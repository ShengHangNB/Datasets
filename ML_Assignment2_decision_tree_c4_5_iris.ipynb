# %% [markdown]
# <a href="https://colab.research.google.com/github/ShengHangNB/Datasets/blob/master/ML_Assignment2_decision_tree_c4_5_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Machine Learning Assignment 2**
#
# Implementation of algorithm - Decision Tree C4.5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ShengHangNB/Datasets/master/iris.csv")
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# check whether there are some duplicated values in the datasets
df.duplicated().sum()

# The results show they are 215 duplicated samples in the datasets,
# I do not drop the duplicated values here because I want to 
# design the function in the algorithm to deal with the duplicated values.
# Out:
# 3

# %%
# check whether thare are some null values for each attribute
df.isnull().any()
# Out:
# sepal length    False
# sepal width     False
# petal length    False
# petal width     False
# class           False
# dtype: bool

# %%
# check the data type and non-null count values for each attribute
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  150 non-null    float64
#  1   sepal width   150 non-null    float64
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Table of statistics for all numerical attributes:
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# get the attributes by using the df.keys() functions,
# then extract all the attributes except for the target name by using the slice method df.keys()[:-1]
attrs = df.keys()[:-1]
print("The attrbutes are: ")
for attr in attrs:
  print(attr)

print("\nThe target is ",df.keys()[-1])
# Out:
# The attrbutes are:
# sepal length
# sepal width
# petal length
# petal width
#
# The target is  class

# %%
# split the datasets into the attributes datasets (input) and target datasets (output)
# X: DataFrame type   y: Series type
print("The number of samples in the total datasets are {}\n".format(df.shape[0]))
X = df[attrs]
y = df.iloc[:,-1]

# For the features datasets,target datasets, split them into the training datasets and testing datasets respectively
# The training datasets accounts for 67% of the total datasets,
# The testing datasets acoounts for 33% of the total datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33,random_state = 47)


print("The number of samples in the training datasets are {}".format(X_train.shape[0]))
print("The number of samples in the testing datasets are {}".format(X_test.shape[0]))
# Out:
# The number of samples in the total datasets are 150
#
# The number of samples in the training datasets are 100
# The number of samples in the testing datasets are 50

# %%
def get_split_pointSet(attr_series):
    '''
      功能:通过二分法将连续属性离散化处理
      array: 传入的一列属性的值，series类型
      返回值：所有划分点的集合,array类型
    '''
    unique_values = np.unique(attr_series)
    result = np.array([(unique_values[i] + unique_values[i+1]) / 2 for i in range(len(unique_values)-1)])

    return np.unique(result)

# %%
def get_discrete_variables(X,attr,split_point):
  '''
    功能：将连续型变量通过分裂点转换为大于分裂点和小于分离点的离散型变量
    X: 传入的数据集, DataFrame
    attr: 需要分割的属性
    split_point：划分点/分割点
  '''
  bins_to_cut = [min(X[attr]),split_point,max(X[attr])]
  labels_to_cut = [attr + ' < ' + str(split_point), attr + ' > ' + str(split_point)]
  categorized_column = pd.cut(X[attr], bins= bins_to_cut , labels = labels_to_cut, include_lowest=True)
  return categorized_column

# %%
def compute_entropy(y):
    '''
      功能：计算信息熵H(D)
      y: 传入的目标值series
      返回值：float类型的计算结果
    '''
    if len(y) < 2:
        return 0.0
    
    freq = y.value_counts(normalize=True)
    
    return -(freq * np.log2(freq + 1e-6)).sum()

# %%
def compute_info_gain_ratio(X,y,attr,split_point_list):
    '''
        计算连续型变量中特定属性的单个分裂点的信息增益
        
        X：包含属性的数据集, DataFrame类型
        y：包含目标值的数据集, Series类型
        attr: 要计算信息增益的属性，字符串类型
        split_point_lst: 分割点，float类型
        
        返回值：信息增益率计算结果，float类型; 最优划分点：float类型
        
    '''
    best_split_point = 0.0
    best_info_gain = 0.0
    split_entropy = 0.0
    print("{}'s splited points' list：{}".format(attr,split_point_list))
    if len(split_point_list) == 0:
      return 0, None

    else:
      for split_point in split_point_list:
          lower_index_boolean = X[attr] < split_point
          lower_X = X[lower_index_boolean]
          lower_y = y[lower_index_boolean]
          
          upper_index_boolean = X[attr] > split_point
          upper_X = X[upper_index_boolean]
          upper_y = y[upper_index_boolean]
          
          Ent_D = compute_entropy(y)
          
          lower_p = len(lower_X) / len(X)
          upper_p = len(upper_X ) / len(X)

          lower_result = lower_p * compute_entropy(lower_y)
          upper_result = upper_p * compute_entropy(upper_y)   
          
          info_gain = Ent_D - (lower_result + upper_result)

          categorized_column = get_discrete_variables(X,attr,split_point)

          split_entropy = compute_entropy(categorized_column)

          if info_gain > best_info_gain:
              best_info_gain = info_gain
              best_split_point = split_point
            
      info_gain_ratio = best_info_gain / split_entropy

      # print("{}特征的最优划分点为：{}".format(attr,best_split_point))
      # print("{}特征的信息增益率为：{}".format(attr,best_info_gain))
      return info_gain_ratio, best_split_point

# %%
class TreeNode:
  def __init__(self,node_name="",default_decision=None):
    self.children = {}
    self.split_point = 0.0
    self.name = node_name
    self.split_attr = None
    self.default_decision = default_decision
    self.decision = None
  
  def make(self,X,y):
    if self.default_decision is None:
      self.default_decision = y.mode()[0]

    print("Node name of this sub datasets: ",self.name)
    print("Input values:")
    print(X)
    print("\nTarget values:")
    print(y)

    if len(X) == 0:
      self.decision = self.default_decision
      print("Specially determining the decision ->", self.decision)
      print("------------------------------------------------------------------------------------------------------------")
      return
         
    else:
      target_unique_values = y.unique()
      if len(target_unique_values) == 1:
        self.decision = target_unique_values[0]
        print("Determining this node as the leaf node")
        print("Determining the decision ->", self.decision)
        print("------------------------------------------------------------------------------------------------------------")
        return

      else:
        max_infoGain_rate = 0.0
        best_split_point = 0.0
        best_split_point_list = []
        print()
        for attr in X.keys():
          split_point_list = get_split_pointSet(X[attr])
          if len(split_point_list) == 0:
            # 没有划分点了，说明对于此属性只有一种取值，因此对结果无任何信息增益，因此跳过此次循环执行下一次循环
            continue

          else:
            infoGain_rate,splited_point = compute_info_gain_ratio(X,y,attr,split_point_list)
            if infoGain_rate > max_infoGain_rate:
              max_infoGain_rate = infoGain_rate
              self.split_attr = attr
              best_split_point_list = split_point_list
              best_split_point = splited_point

        self.split_point = best_split_point

        if self.split_point != 0.0:

          X_copy = X.copy()
          discrete_class = self.split_attr + '-group'
          X_copy.loc[:,discrete_class] = get_discrete_variables(X_copy,self.split_attr,self.split_point)
          print("\nSplited by {} attribute，its information gain ratio：{}".format(self.split_attr,max_infoGain_rate)) 
          
          for value in X_copy[discrete_class].unique():
            index_boolean = X_copy[discrete_class] == value
            self.children[value] = TreeNode(node_name = value, default_decision=self.default_decision)
            
            # print("Its splited points' list：{}".format(best_split_point_list))
            print("Not enough to determine the decision, child's node is split below:")
            self.children[value].make(X[index_boolean],y[index_boolean])
        
        else:
          print('All attributes have no information gain (ratio)')
          y_mode = y.mode()

          if len(y_mode) == 1:
            better_decision = y_mode[0]
            print("Determining this node as the leaf node")
            print("Choosing the better decision ->",better_decision)
            self.decision = better_decision
            print("------------------------------------------------------------------------------------------------------------")

          else:
            decision = y_mode[0]
            print("Can not choose the better decision, these two samples have the sample inputs but different output")
            print("Determining this node as the leaf node")
            print("Just Choose the decision ->",decision)
            self.decision = decision
            print("------------------------------------------------------------------------------------------------------------")
          return

# %%
class TreeC4_5:
  def __init__(self):
    self.root = None

  def fit(self,X,y):
    self.root = TreeNode()
    self.root.make(X,y)

  def predict(self,samples):
    decision_list = []
    for sample_index in range(len(samples)):
      sample = samples.iloc[sample_index]
      decision = self.make_decision(sample) 
      decision_list.append(decision)
    return np.array(decision_list)

  def make_decision(self,sample):
    current_node = self.root
    while current_node.decision is None:
      attribute_to_split = current_node.split_attr
      attribute_value = sample[attribute_to_split]
      print("Testing: ",attribute_to_split,"->",attribute_value)
      
      if attribute_value > current_node.split_point:
        next_attr = current_node.split_attr + ' > ' + str(current_node.split_point)
      
      else:
        next_attr = current_node.split_attr + ' < ' + str(current_node.split_point)
          
      current_node = current_node.children[next_attr]

    print("Decision: ",current_node.decision)
    return current_node.decision

# %%
dt4_5 = TreeC4_5()
dt4_5.fit(X_train,y_train)
# Out:
# Node name of this sub datasets:
# Input values:
#      sepal length  sepal width  petal length  petal width
# 41            4.5          2.3           1.3          0.3
# 60            5.0          2.0           3.5          1.0
# 115           6.4          3.2           5.3          2.3
# 58            6.6          2.9           4.6          1.3
# 17            5.1          3.5           1.4          0.3
# ..            ...          ...           ...          ...
# 72            6.3          2.5           4.9          1.5
# 8             4.4          2.9           1.4          0.2
# 71            6.1          2.8           4.0          1.3
# 134           6.1          2.6           5.6          1.4
# 135           7.7          3.0           6.1          2.3
#
# [100 rows x 4 columns]
#
# Target values:
# 41         Iris-setosa
# 60     Iris-versicolor
# 115     Iris-virginica
# 58     Iris-versicolor
# 17         Iris-setosa
#             ...
# 72     Iris-versicolor
# 8          Iris-setosa
# 71     Iris-versicolor
# 134     Iris-virginica
# 135     Iris-virginica
# Name: class, Length: 100, dtype: object
#
# sepal length's splited points' list：[4.35 4.45 4.55 4.65 4.75 4.85 4.95 5.05 5.15 5.25 5.35 5.45 5.55 5.65
#  5.75 5.85 5.95 6.05 6.15 6.25 6.35 6.45 6.55 6.65 6.75 6.85 6.95 7.1
#  7.3  7.55]
# sepal width's splited points' list：[2.1  2.25 2.35 2.45 2.55 2.65 2.75 2.85 2.95 3.05 3.15 3.25 3.35 3.45
#  3.55 3.65 3.75 3.85 4.   4.15]
# petal length's splited points' list：[1.15 1.25 1.35 1.45 1.55 1.65 2.35 3.15 3.4  3.55 3.65 3.75 3.85 3.95
#  4.05 4.15 4.25 4.35 4.45 4.55 4.65 4.75 4.85 4.95 5.05 5.15 5.25 5.35
#  5.45 5.55 5.65 5.75 5.85 6.   6.5 ]
# petal width's splited points' list：[0.15 0.25 0.35 0.45 0.55 0.8  1.05 1.15 1.25 1.35 1.45 1.55 1.65 1.75
#  1.85 1.95 2.05 2.15 2.25 2.35 2.45]
#
# Splited by petal length attribute，its information gain ratio：10.908358588059302
# Not enough to determine the decision, child's node is split below:
# Node name of this sub datasets:  petal length < 2.35
# Input values:
#     sepal length  sepal width  petal length  petal width
# 41           4.5          2.3           1.3          0.3
# 17           5.1          3.5           1.4          0.3
# 45           4.8          3.0           1.4          0.3
# 38           4.4          3.0           1.3          0.2
# 13           4.3          3.0           1.1          0.1
# 20           5.4          3.4           1.7          0.2
# 29           4.7          3.2           1.6          0.2
# 32           5.2          4.1           1.5          0.1
# 12           4.8          3.0           1.4          0.1
# 25           5.0          3.0           1.6          0.2
# 6            4.6          3.4           1.4          0.3
# 26           5.0          3.4           1.6          0.4
# 16           5.4          3.9           1.3          0.4
# 2            4.7          3.2           1.3          0.2
# 28           5.2          3.4           1.4          0.2
# 31           5.4          3.4           1.5          0.4
# 42           4.4          3.2           1.3          0.2
# 43           5.0          3.5           1.6          0.6
# 19           5.1          3.8           1.5          0.3
# 21           5.1          3.7           1.5          0.4
# 27           5.2          3.5           1.5          0.2
# 33           5.5          4.2           1.4          0.2
# 9            4.9          3.1           1.5          0.1
# 35           5.0          3.2           1.2          0.2
# 4            5.0          3.6           1.4          0.2
# 34           4.9          3.1           1.5          0.1
# 48           5.3          3.7           1.5          0.2
# 7            5.0          3.4           1.5          0.2
# 23           5.1          3.3           1.7          0.5
# 8            4.4          2.9           1.4          0.2
#
# Target values:
# 41    Iris-setosa
# 17    Iris-setosa
# 45    Iris-setosa
# 38    Iris-setosa
# 13    Iris-setosa
# 20    Iris-setosa
# 29    Iris-setosa
# 32    Iris-setosa
# 12    Iris-setosa
# 25    Iris-setosa
# 6     Iris-setosa
# 26    Iris-setosa
# 16    Iris-setosa
# 2     Iris-setosa
# 28    Iris-setosa
# 31    Iris-setosa
# 42    Iris-setosa
# 43    Iris-setosa
# 19    Iris-setosa
# 21    Iris-setosa
# 27    Iris-setosa
# 33    Iris-setosa
# 9     Iris-setosa
# 35    Iris-setosa
# 4     Iris-setosa
# 34    Iris-setosa
# 48    Iris-setosa
# 7     Iris-setosa
# 23    Iris-setosa
# 8     Iris-setosa
# Name: class, dtype: object
# Determining this node as the leaf node
# Determining the decision -> Iris-setosa
# ------------------------------------------------------------------------------------------------------------
# Not enough to determine the decision, child's node is split below:
# Node name of this sub datasets:  petal length > 2.35
# Input values:
#      sepal length  sepal width  petal length  petal width
# 60            5.0          2.0           3.5          1.0
# 115           6.4          3.2           5.3          2.3
# 58            6.6          2.9           4.6          1.3
# 61            5.9          3.0           4.2          1.5
# 148           6.2          3.4           5.4          2.3
# ..            ...          ...           ...          ...
# 80            5.5          2.4           3.8          1.1
# 72            6.3          2.5           4.9          1.5
# 71            6.1          2.8           4.0          1.3
# 134           6.1          2.6           5.6          1.4
# 135           7.7          3.0           6.1          2.3
#
# [70 rows x 4 columns]
#
# Target values:
# 60     Iris-versicolor
# 115     Iris-virginica
# 58     Iris-versicolor
# 61     Iris-versicolor
# 148     Iris-virginica
#             ...
# 80     Iris-versicolor
# 72     Iris-versicolor
# 71     Iris-versicolor
# 134     Iris-virginica
# 135     Iris-virginica
# Name: class, Length: 70, dtype: object
#
# sepal length's splited points' list：[4.95 5.05 5.15 5.3  5.45 5.55 5.65 5.75 5.85 5.95 6.05 6.15 6.25 6.35
#  6.45 6.55 6.65 6.75 6.85 6.95 7.1  7.3  7.55]
# sepal width's splited points' list：[2.1  2.25 2.35 2.45 2.55 2.65 2.75 2.85 2.95 3.05 3.15 3.25 3.35 3.5 ]
# petal length's splited points' list：[3.15 3.4  3.55 3.65 3.75 3.85 3.95 4.05 4.15 4.25 4.35 4.45 4.55 4.65
#  4.75 4.85 4.95 5.05 5.15 5.25 5.35 5.45 5.55 5.65 5.75 5.85 6.   6.5 ]
# petal width's splited points' list：[1.05 1.15 1.25 1.35 1.45 1.55 1.65 1.75 1.85 1.95 2.05 2.15 2.25 2.35
#  2.45]
#
# Splited by petal length attribute，its information gain ratio：5.694145429762569
# Not enough to determine the decision, child's node is split below:
# Node name of this sub datasets:  petal length < 5.05
# Input values:
#      sepal length  sepal width  petal length  petal width
# 60            5.0          2.0           3.5          1.0
# 58            6.6          2.9           4.6          1.3
# 61            5.9          3.0           4.2          1.5
# 63            6.1          2.9           4.7          1.4
# 93            5.0          2.3           3.3          1.0
# 69            5.6          2.5           3.9          1.1
# 106           4.9          2.5           4.5          1.7
# 76            6.8          2.8           4.8          1.4
# 82            5.8          2.7           3.9          1.2
# 98            5.1          2.5           3.0          1.1
# 89            5.5          2.5           4.0          1.3
# 126           6.2          2.8           4.8          1.8
# 75            6.6          3.0           4.4          1.4
# 84            5.4          3.0           4.5          1.5
# 51            6.4          3.2           4.5          1.5
# 90            5.5          2.6           4.4          1.2
# 85            6.0          3.4           4.5          1.6
# 67            5.8          2.7           4.1          1.0
# 68            6.2          2.2           4.5          1.5
# 77            6.7          3.0           5.0          1.7
# 56            6.3          3.3           4.7          1.6
# 74            6.4          2.9           4.3          1.3
# 79            5.7          2.6           3.5          1.0
# 86            6.7          3.1           4.7          1.5
# 70            5.9          3.2           4.8          1.8
# 57            4.9          2.4           3.3          1.0
# 52            6.9          3.1           4.9          1.5
# 81            5.5          2.4           3.7          1.0
# 95            5.7          3.0           4.2          1.2
# 66            5.6          3.0           4.5          1.5
# 64            5.6          2.9           3.6          1.3
# 92            5.8          2.6           4.0          1.2
# 73            6.1          2.8           4.7          1.2
# 53            5.5          2.3           4.0          1.3
# 123           6.3          2.7           4.9          1.8
# 87            6.3          2.3           4.4          1.3
# 65            6.7          3.1           4.4          1.4
# 50            7.0          3.2           4.7          1.4
# 55            5.7          2.8           4.5          1.3
# 113           5.7          2.5           5.0          2.0
# 59            5.2          2.7           3.9          1.4
# 80            5.5          2.4           3.8          1.1
# 72            6.3          2.5           4.9          1.5
# 71            6.1          2.8           4.0          1.3
#
# Target values:
# 60     Iris-versicolor
# 58     Iris-versicolor
# 61     Iris-versicolor
# 63     Iris-versicolor
# 93     Iris-versicolor
# 69     Iris-versicolor
# 106     Iris-virginica
# 76     Iris-versicolor
# 82     Iris-versicolor
# 98     Iris-versicolor
# 89     Iris-versicolor
# 126     Iris-virginica
# 75     Iris-versicolor
# 84     Iris-versicolor
# 51     Iris-versicolor
# 90     Iris-versicolor
# 85     Iris-versicolor
# 67     Iris-versicolor
# 68     Iris-versicolor
# 77     Iris-versicolor
# 56     Iris-versicolor
# 74     Iris-versicolor
# 79     Iris-versicolor
# 86     Iris-versicolor
# 70     Iris-versicolor
# 57     Iris-versicolor
# 52     Iris-versicolor
# 81     Iris-versicolor
# 95     Iris-versicolor
# 66     Iris-versicolor
# 64     Iris-versicolor
# 92     Iris-versicolor
# 73     Iris-versicolor
# 53     Iris-versicolor
# 123     Iris-virginica
# 87     Iris-versicolor
# 65     Iris-versicolor
# 50     Iris-versicolor
# 55     Iris-versicolor
# 113     Iris-virginica
# 59     Iris-versicolor
# 80     Iris-versicolor
# 72     Iris-versicolor
# 71     Iris-versicolor
# Name: class, dtype: object
#
# sepal length's splited points' list：[4.95 5.05 5.15 5.3  5.45 5.55 5.65 5.75 5.85 5.95 6.05 6.15 6.25 6.35
#  6.5  6.65 6.75 6.85 6.95]
# sepal width's splited points' list：[2.1  2.25 2.35 2.45 2.55 2.65 2.75 2.85 2.95 3.05 3.15 3.25 3.35]
# petal length's splited points' list：[3.15 3.4  3.55 3.65 3.75 3.85 3.95 4.05 4.15 4.25 4.35 4.45 4.55 4.65
#  4.75 4.85 4.95]
# petal width's splited points' list：[1.05 1.15 1.25 1.35 1.45 1.55 1.65 1.75 1.9 ]
#
# Splited by petal width attribute，its information gain ratio：2.008289614590452
# Not enough to determine the decision, child's node is split below:
# Node name of this sub datasets:  petal width < 1.65
# Input values:
#     sepal length  sepal width  petal length  petal width
# 60           5.0          2.0           3.5          1.0
# 58           6.6          2.9           4.6          1.3
# 61           5.9          3.0           4.2          1.5
# 63           6.1          2.9           4.7          1.4
# 93           5.0          2.3           3.3          1.0
# 69           5.6          2.5           3.9          1.1
# 76           6.8          2.8           4.8          1.4
# 82           5.8          2.7           3.9          1.2
# 98           5.1          2.5           3.0          1.1
# 89           5.5          2.5           4.0          1.3
# 75           6.6          3.0           4.4          1.4
# 84           5.4          3.0           4.5          1.5
# 51           6.4          3.2           4.5          1.5
# 90           5.5          2.6           4.4          1.2
# 85           6.0          3.4           4.5          1.6
# 67           5.8          2.7           4.1          1.0
# 68           6.2          2.2           4.5          1.5
# 56           6.3          3.3           4.7          1.6
# 74           6.4          2.9           4.3          1.3
# 79           5.7          2.6           3.5          1.0
# 86           6.7          3.1           4.7          1.5
# 57           4.9          2.4           3.3          1.0
# 52           6.9          3.1           4.9          1.5
# 81           5.5          2.4           3.7          1.0
# 95           5.7          3.0           4.2          1.2
# 66           5.6          3.0           4.5          1.5
# 64           5.6          2.9           3.6          1.3
# 92           5.8          2.6           4.0          1.2
# 73           6.1          2.8           4.7          1.2
# 53           5.5          2.3           4.0          1.3
# 87           6.3          2.3           4.4          1.3
# 65           6.7          3.1           4.4          1.4
# 50           7.0          3.2           4.7          1.4
# 55           5.7          2.8           4.5          1.3
# 59           5.2          2.7           3.9          1.4
# 80           5.5          2.4           3.8          1.1
# 72           6.3          2.5           4.9          1.5
# 71           6.1          2.8           4.0          1.3
#
# Target values:
# 60    Iris-versicolor
# 58    Iris-versicolor
# 61    Iris-versicolor
# 63    Iris-versicolor
# 93    Iris-versicolor
# 69    Iris-versicolor
# 76    Iris-versicolor
# 82    Iris-versicolor
# 98    Iris-versicolor
# 89    Iris-versicolor
# 75    Iris-versicolor
# 84    Iris-versicolor
# 51    Iris-versicolor
# 90    Iris-versicolor
# 85    Iris-versicolor
# 67    Iris-versicolor
# 68    Iris-versicolor
# 56    Iris-versicolor
# 74    Iris-versicolor
# 79    Iris-versicolor
# 86    Iris-versicolor
# 57    Iris-versicolor
# 52    Iris-versicolor
# 81    Iris-versicolor
# 95    Iris-versicolor
# 66    Iris-versicolor
# 64    Iris-versicolor
# 92    Iris-versicolor
# 73    Iris-versicolor
# 53    Iris-versicolor
# 87    Iris-versicolor
# 65    Iris-versicolor
# 50    Iris-versicolor
# 55    Iris-versicolor
# 59    Iris-versicolor
# 80    Iris-versicolor
# 72    Iris-versicolor
# 71    Iris-versicolor
# Name: class, dtype: object
# Determining this node as the leaf node
# Determining the decision -> Iris-versicolor
# ------------------------------------------------------------------------------------------------------------
# Not enough to determine the decision, child's node is split below:
# Node name of this sub datasets:  petal width > 1.65
# Input values:
#      sepal length  sepal width  petal length  petal width
# 106           4.9          2.5           4.5          1.7
# 126           6.2          2.8           4.8          1.8
# 77            6.7          3.0           5.0          1.7
# 70            5.9          3.2           4.8          1.8
# 123           6.3          2.7           4.9          1.8
# 113           5.7          2.5           5.0          2.0
#
# Target values:
# 106     Iris-virginica
# 126     Iris-virginica
# 77     Iris-versicolor
# 70     Iris-versicolor
# 123     Iris-virginica
# 113     Iris-virginica
# Name: class, dtype: object
#
# sepal length's splited points' list：[5.3  5.8  6.05 6.25 6.5 ]
# sepal width's splited points' list：[2.6  2.75 2.9  3.1 ]
# petal length's splited points' list：[4.65 4.85 4.95]
# petal width's splited points' list：[1.75 1.9 ]
#
# Splited by sepal width attribute，its information gain ratio：1.41271814173562
# Not enough to determine the decision, child's node is split below:
# Node name of this sub datasets:  sepal width < 2.9
# Input values:
#      sepal length  sepal width  petal length  petal width
# 106           4.9          2.5           4.5          1.7
# 126           6.2          2.8           4.8          1.8
# 123           6.3          2.7           4.9          1.8
# 113           5.7          2.5           5.0          2.0
#
# Target values:
# 106    Iris-virginica
# 126    Iris-virginica
# 123    Iris-virginica
# 113    Iris-virginica
# Name: class, dtype: object
# Determining this node as the leaf node
# Determining the decision -> Iris-virginica
# ------------------------------------------------------------------------------------------------------------
# Not enough to determine the decision, child's node is split below:
# Node name of this sub datasets:  sepal width > 2.9
# Input values:
#     sepal length  sepal width  petal length  petal width
# 77           6.7          3.0           5.0          1.7
# 70           5.9          3.2           4.8          1.8
#
# Target values:
# 77    Iris-versicolor
# 70    Iris-versicolor
# Name: class, dtype: object
# Determining this node as the leaf node
# Determining the decision -> Iris-versicolor
# ------------------------------------------------------------------------------------------------------------
# Not enough to determine the decision, child's node is split below:
# Node name of this sub datasets:  petal length > 5.05
# Input values:
#      sepal length  sepal width  petal length  petal width
# 115           6.4          3.2           5.3          2.3
# 148           6.2          3.4           5.4          2.3
# 143           6.8          3.2           5.9          2.3
# 144           6.7          3.3           5.7          2.5
# 130           7.4          2.8           6.1          1.9
# 132           6.4          2.8           5.6          2.2
# 137           6.4          3.1           5.5          1.8
# 109           7.2          3.6           6.1          2.5
# 83            6.0          2.7           5.1          1.6
# 112           6.8          3.0           5.5          2.1
# 129           7.2          3.0           5.8          1.6
# 104           6.5          3.0           5.8          2.2
# 111           6.4          2.7           5.3          1.9
# 128           6.4          2.8           5.6          2.1
# 133           6.3          2.8           5.1          1.5
# 142           5.8          2.7           5.1          1.9
# 118           7.7          2.6           6.9          2.3
# 139           6.9          3.1           5.4          2.1
# 101           5.8          2.7           5.1          1.9
# 110           6.5          3.2           5.1          2.0
# 149           5.9          3.0           5.1          1.8
# 145           6.7          3.0           5.2          2.3
# 114           5.8          2.8           5.1          2.4
# 147           6.5          3.0           5.2          2.0
# 134           6.1          2.6           5.6          1.4
# 135           7.7          3.0           6.1          2.3
#
# Target values:
# 115     Iris-virginica
# 148     Iris-virginica
# 143     Iris-virginica
# 144     Iris-virginica
# 130     Iris-virginica
# 132     Iris-virginica
# 137     Iris-virginica
# 109     Iris-virginica
# 83     Iris-versicolor
# 112     Iris-virginica
# 129     Iris-virginica
# 104     Iris-virginica
# 111     Iris-virginica
# 128     Iris-virginica
# 133     Iris-virginica
# 142     Iris-virginica
# 118     Iris-virginica
# 139     Iris-virginica
# 101     Iris-virginica
# 110     Iris-virginica
# 149     Iris-virginica
# 145     Iris-virginica
# 114     Iris-virginica
# 147     Iris-virginica
# 134     Iris-virginica
# 135     Iris-virginica
# Name: class, dtype: object
#
# sepal length's splited points' list：[5.85 5.95 6.05 6.15 6.25 6.35 6.45 6.6  6.75 6.85 7.05 7.3  7.55]
# sepal width's splited points' list：[2.65 2.75 2.9  3.05 3.15 3.25 3.35 3.5 ]
# petal length's splited points' list：[5.15 5.25 5.35 5.45 5.55 5.65 5.75 5.85 6.   6.5 ]
# petal width's splited points' list：[1.45 1.55 1.7  1.85 1.95 2.05 2.15 2.25 2.35 2.45]
#
# Splited by sepal width attribute，its information gain ratio：0.36220467719293004
# Not enough to determine the decision, child's node is split below:
# Node name of this sub datasets:  sepal width > 2.75
# Input values:
#      sepal length  sepal width  petal length  petal width
# 115           6.4          3.2           5.3          2.3
# 148           6.2          3.4           5.4          2.3
# 143           6.8          3.2           5.9          2.3
# 144           6.7          3.3           5.7          2.5
# 130           7.4          2.8           6.1          1.9
# 132           6.4          2.8           5.6          2.2
# 137           6.4          3.1           5.5          1.8
# 109           7.2          3.6           6.1          2.5
# 112           6.8          3.0           5.5          2.1
# 129           7.2          3.0           5.8          1.6
# 104           6.5          3.0           5.8          2.2
# 128           6.4          2.8           5.6          2.1
# 133           6.3          2.8           5.1          1.5
# 139           6.9          3.1           5.4          2.1
# 110           6.5          3.2           5.1          2.0
# 149           5.9          3.0           5.1          1.8
# 145           6.7          3.0           5.2          2.3
# 114           5.8          2.8           5.1          2.4
# 147           6.5          3.0           5.2          2.0
# 135           7.7          3.0           6.1          2.3
#
# Target values:
# 115    Iris-virginica
# 148    Iris-virginica
# 143    Iris-virginica
# 144    Iris-virginica
# 130    Iris-virginica
# 132    Iris-virginica
# 137    Iris-virginica
# 109    Iris-virginica
# 112    Iris-virginica
# 129    Iris-virginica
# 104    Iris-virginica
# 128    Iris-virginica
# 133    Iris-virginica
# 139    Iris-virginica
# 110    Iris-virginica
# 149    Iris-virginica
# 145    Iris-virginica
# 114    Iris-virginica
# 147    Iris-virginica
# 135    Iris-virginica
# Name: class, dtype: object
# Determining this node as the leaf node
# Determining the decision -> Iris-virginica
# ------------------------------------------------------------------------------------------------------------
# Not enough to determine the decision, child's node is split below:
# Node name of this sub datasets:  sepal width < 2.75
# Input values:
#      sepal length  sepal width  petal length  petal width
# 83            6.0          2.7           5.1          1.6
# 111           6.4          2.7           5.3          1.9
# 142           5.8          2.7           5.1          1.9
# 118           7.7          2.6           6.9          2.3
# 101           5.8          2.7           5.1          1.9
# 134           6.1          2.6           5.6          1.4
#
# Target values:
# 83     Iris-versicolor
# 111     Iris-virginica
# 142     Iris-virginica
# 118     Iris-virginica
# 101     Iris-virginica
# 134     Iris-virginica
# Name: class, dtype: object
#
# sepal length's splited points' list：[5.9  6.05 6.25 7.05]
# sepal width's splited points' list：[2.65]
# petal length's splited points' list：[5.2  5.45 6.25]
# petal width's splited points' list：[1.5  1.75 2.1 ]
#
# Splited by petal width attribute，its information gain ratio：0.4871978592251383
# Not enough to determine the decision, child's node is split below:
# Node name of this sub datasets:  petal width < 1.75
# Input values:
#      sepal length  sepal width  petal length  petal width
# 83            6.0          2.7           5.1          1.6
# 134           6.1          2.6           5.6          1.4
#
# Target values:
# 83     Iris-versicolor
# 134     Iris-virginica
# Name: class, dtype: object
#
# sepal length's splited points' list：[6.05]
# sepal width's splited points' list：[2.65]
# petal length's splited points' list：[5.35]
# petal width's splited points' list：[1.5]
#
# Splited by sepal length attribute，its information gain ratio：1.0
# Not enough to determine the decision, child's node is split below:
# Node name of this sub datasets:  sepal length < 6.05
# Input values:
#     sepal length  sepal width  petal length  petal width
# 83           6.0          2.7           5.1          1.6
#
# Target values:
# 83    Iris-versicolor
# Name: class, dtype: object
# Determining this node as the leaf node
# Determining the decision -> Iris-versicolor
# ------------------------------------------------------------------------------------------------------------
# Not enough to determine the decision, child's node is split below:
# Node name of this sub datasets:  sepal length > 6.05
# Input values:
#      sepal length  sepal width  petal length  petal width
# 134           6.1          2.6           5.6          1.4
#
# Target values:
# 134    Iris-virginica
# Name: class, dtype: object
# Determining this node as the leaf node
# Determining the decision -> Iris-virginica
# ------------------------------------------------------------------------------------------------------------
# Not enough to determine the decision, child's node is split below:
# Node name of this sub datasets:  petal width > 1.75
# Input values:
#      sepal length  sepal width  petal length  petal width
# 111           6.4          2.7           5.3          1.9
# 142           5.8          2.7           5.1          1.9
# 118           7.7          2.6           6.9          2.3
# 101           5.8          2.7           5.1          1.9
#
# Target values:
# 111    Iris-virginica
# 142    Iris-virginica
# 118    Iris-virginica
# 101    Iris-virginica
# Name: class, dtype: object
# Determining this node as the leaf node
# Determining the decision -> Iris-virginica
# ------------------------------------------------------------------------------------------------------------

# %%
  decisions = dt4_5.predict(X_test)
results = decisions == y_test
accuracy = sum(results) / len(results)
print("Accuracy: ", accuracy)
# Out:
# Testing:  petal length -> 1.5
# Decision:  Iris-setosa
# Testing:  petal length -> 1.4
# Decision:  Iris-setosa
# Testing:  petal length -> 4.2
# Testing:  petal length -> 4.2
# Testing:  petal width -> 1.3
# Decision:  Iris-versicolor
# Testing:  petal length -> 1.7
# Decision:  Iris-setosa
# Testing:  petal length -> 1.5
# Decision:  Iris-setosa
# Testing:  petal length -> 6.6
# Testing:  petal length -> 6.6
# Testing:  sepal width -> 3.0
# Decision:  Iris-virginica
# Testing:  petal length -> 4.1
# Testing:  petal length -> 4.1
# Testing:  petal width -> 1.3
# Decision:  Iris-versicolor
# Testing:  petal length -> 5.7
# Testing:  petal length -> 5.7
# Testing:  sepal width -> 3.2
# Decision:  Iris-virginica
# Testing:  petal length -> 4.2
# Testing:  petal length -> 4.2
# Testing:  petal width -> 1.3
# Decision:  Iris-versicolor
# Testing:  petal length -> 1.4
# Decision:  Iris-setosa
# Testing:  petal length -> 5.5
# Testing:  petal length -> 5.5
# Testing:  sepal width -> 3.0
# Decision:  Iris-virginica
# Testing:  petal length -> 1.5
# Decision:  Iris-setosa
# Testing:  petal length -> 4.1
# Testing:  petal length -> 4.1
# Testing:  petal width -> 1.3
# Decision:  Iris-versicolor
# Testing:  petal length -> 6.4
# Testing:  petal length -> 6.4
# Testing:  sepal width -> 3.8
# Decision:  Iris-virginica
# Testing:  petal length -> 4.9
# Testing:  petal length -> 4.9
# Testing:  petal width -> 1.8
# Testing:  sepal width -> 3.0
# Decision:  Iris-versicolor
# Testing:  petal length -> 5.9
# Testing:  petal length -> 5.9
# Testing:  sepal width -> 3.0
# Decision:  Iris-virginica
# Testing:  petal length -> 4.0
# Testing:  petal length -> 4.0
# Testing:  petal width -> 1.0
# Decision:  Iris-versicolor
# Testing:  petal length -> 1.4
# Decision:  Iris-setosa
# Testing:  petal length -> 1.7
# Decision:  Iris-setosa
# Testing:  petal length -> 1.3
# Decision:  Iris-setosa
# Testing:  petal length -> 5.6
# Testing:  petal length -> 5.6
# Testing:  sepal width -> 3.1
# Decision:  Iris-virginica
# Testing:  petal length -> 4.6
# Testing:  petal length -> 4.6
# Testing:  petal width -> 1.5
# Decision:  Iris-versicolor
# Testing:  petal length -> 4.9
# Testing:  petal length -> 4.9
# Testing:  petal width -> 2.0
# Testing:  sepal width -> 2.8
# Decision:  Iris-virginica
# Testing:  petal length -> 5.0
# Testing:  petal length -> 5.0
# Testing:  petal width -> 1.5
# Decision:  Iris-versicolor
# Testing:  petal length -> 5.7
# Testing:  petal length -> 5.7
# Testing:  sepal width -> 3.3
# Decision:  Iris-virginica
# Testing:  petal length -> 6.7
# Testing:  petal length -> 6.7
# Testing:  sepal width -> 3.8
# Decision:  Iris-virginica
# Testing:  petal length -> 4.5
# Testing:  petal length -> 4.5
# Testing:  petal width -> 1.5
# Decision:  Iris-versicolor
# Testing:  petal length -> 5.6
# Testing:  petal length -> 5.6
# Testing:  sepal width -> 3.4
# Decision:  Iris-virginica
# Testing:  petal length -> 1.6
# Decision:  Iris-setosa
# Testing:  petal length -> 1.9
# Decision:  Iris-setosa
# Testing:  petal length -> 5.8
# Testing:  petal length -> 5.8
# Testing:  sepal width -> 2.5
# Testing:  petal width -> 1.8
# Decision:  Iris-virginica
# Testing:  petal length -> 4.6
# Testing:  petal length -> 4.6
# Testing:  petal width -> 1.4
# Decision:  Iris-versicolor
# Testing:  petal length -> 6.3
# Testing:  petal length -> 6.3
# Testing:  sepal width -> 2.9
# Decision:  Iris-virginica
# Testing:  petal length -> 1.6
# Decision:  Iris-setosa
# Testing:  petal length -> 4.8
# Testing:  petal length -> 4.8
# Testing:  petal width -> 1.8
# Testing:  sepal width -> 3.0
# Decision:  Iris-versicolor
# Testing:  petal length -> 1.5
# Decision:  Iris-setosa
# Testing:  petal length -> 1.9
# Decision:  Iris-setosa
# Testing:  petal length -> 1.4
# Decision:  Iris-setosa
# Testing:  petal length -> 5.1
# Testing:  petal length -> 5.1
# Testing:  sepal width -> 3.1
# Decision:  Iris-virginica
# Testing:  petal length -> 1.3
# Decision:  Iris-setosa
# Testing:  petal length -> 4.3
# Testing:  petal length -> 4.3
# Testing:  petal width -> 1.3
# Decision:  Iris-versicolor
# Testing:  petal length -> 1.2
# Decision:  Iris-setosa
# Testing:  petal length -> 6.0
# Testing:  petal length -> 6.0
# Testing:  sepal width -> 3.3
# Decision:  Iris-virginica
# Testing:  petal length -> 1.5
# Decision:  Iris-setosa
# Testing:  petal length -> 6.7
# Testing:  petal length -> 6.7
# Testing:  sepal width -> 2.8
# Decision:  Iris-virginica
# Testing:  petal length -> 1.0
# Decision:  Iris-setosa
# Testing:  petal length -> 6.0
# Testing:  petal length -> 6.0
# Testing:  sepal width -> 3.2
# Decision:  Iris-virginica
# Testing:  petal length -> 1.6
# Decision:  Iris-setosa
# Testing:  petal length -> 5.6
# Testing:  petal length -> 5.6
# Testing:  sepal width -> 2.9
# Decision:  Iris-virginica
# Testing:  petal length -> 5.0
# Testing:  petal length -> 5.0
# Testing:  petal width -> 1.9
# Testing:  sepal width -> 2.5
# Decision:  Iris-virginica
# Accuracy:  0.94

# %%
from sklearn import tree 
import graphviz   

clf = tree.DecisionTreeClassifier(criterion="entropy",random_state=46)
clf = clf.fit(X_train,y_train)

# %%
decisions = clf.predict(X_test)
result = [decision == target for decision,target in zip(decisions,y_test)]
accuracy = sum(result)/len(result)
print('Accuracy:',accuracy)
# Out:
# Accuracy: 0.96

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y, test_size=0.33,random_state=47)
clf = tree.DecisionTreeClassifier(criterion="entropy",max_depth=3)
clf.fit(x_train,y_train)
dot_data = tree.export_graphviz(clf,out_file=None,feature_names=list(x_train.columns.values),filled=True,rounded=True,special_characters=True)
graphOfTree = graphviz.Source(dot_data)
graphOfTree
